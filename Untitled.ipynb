# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df.head(5)
# Out:
#      City     district                                              Адрес  \
# 0  Алматы  Алмалинский                       Алмалинский район по Толе-би
# 1  Алматы          NaN                                      Егизбаева 5к2
# 2  Алматы          NaN                                Тимирязова Гагарина
# 3  Алматы          NaN                    Алматы, Мега, Саяхат, Жаs Канат
# 4  Алматы     Коктем-3  Квартира находится в Коктем-3, дом 1 (Бухар Жы...
#
#                  street zh_k_name photos  monthlyExpensePerPerson moveInStart  \
# 0               Толе-би       NaN     []                      NaN         NaN
# 1             Егизбаева  Ala Park     []                  65000.0         NaN
# 2            Тимирязова       NaN     []                  75000.0         NaN
# 3                   NaN       NaN     []                      NaN         NaN
# 4  Бухар Жырау Весновка       NaN     []                 125000.0  2024-10-20
#
# ...

# %%
excel_file = "output.xlsx"
df.to_excel(excel_file, index=False, engine='openpyxl')
